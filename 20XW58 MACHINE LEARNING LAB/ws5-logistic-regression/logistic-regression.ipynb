# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

df = pd.read_csv(r"D:/PSG/PSG-Z/SEM 5/20XW58 MACHINE LEARNING LAB/ws5-logistic-regression/datasets/data.csv")
# print(df)

del df['id']

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0         0.2419  ...          17.33           184.60      2019.0
# 1         0.1812  ...          23.41           158.80      1956.0
# 2         0.2069  ...          25.53           152.50      1709.0
# 3         0.2597  ...          26.50            98.87       567.7
# 4         0.1809  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  Unnamed: 32
# 0          0.4601                  0.11890          NaN
# 1          0.2750                  0.08902          NaN
# 2          0.3613                  0.08758          NaN
# 3          0.6638                  0.17300          NaN
# 4          0.2364                  0.07678          NaN
#
# [5 rows x 32 columns]

# %%
features = df.columns
features = list(features)
features = features[1:len(features)-1]
print(len(features))
# Out:
# 30

# %%
# removing multicollinearity
final_features = [x for x in features]
CR = df[features].corr().values.tolist()

for i in range(len(CR)):
    for j in range(i+1,len(CR)):
        if abs(CR[i][j])>0.7 and features[i] in final_features:
            final_features.remove(features[i])

final_features.append('diagnosis')
print(final_features)
# Out:
# ['symmetry_mean', 'texture_se', 'smoothness_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'texture_worst', 'smoothness_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst', 'diagnosis']

# %%
features_list = []
for i in range(0,len(final_features)-1):
    features_list.append(np.array(df[final_features[i]]))
    
y = df[final_features[len(final_features)-1]]

for i in range(len(y)):
    if y[i]=='B':
        y[i]=0
    elif y[i]=='M':
        y[i]=1

# print(features_list)
# for i in y:
#     print(i)

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
def logistic_regression(x,y):
    W = np.random.rand(x.shape[1])
    convergence = False
    eta = 0.01
    DATAPOINTS_SIZE = len(x)
#     for i in range(len(x[0])+1):
#         W.append(0)
#     W = np.array(W)
    print(W)
    y_cap = []
    
    while not convergence:
        wTx = W[0]*1
        congergence = True
        sigmoid_values=[]
        for i in range(0,DATAPOINTS_SIZE):
            
            wTx = W.dot(x[i])
            print(wTx)
            sig_value = sigmoid(wTx)
#             sigmoid_values.append(value)
            if(sig_value>=eta):
                y_cap.append(1)
            else:
                y_cap.append(0)
            
            if y_cap[i] != y[i]:
                w = w + (y[i]-sig_value)*eta*x_data[i]
                convergence = False
        print(y_cap,y)
        break

# %%
# logistic_regression(features_list,y)
# print(features_list)

x_data = df[final_features[0:len(final_features)-1]]
y_data = y
# print(df_features)

X_train , X_test , y_train , y_test = train_test_split(x_data.to_numpy(), y_data.to_numpy(), test_size=0.33)

logistic_regression(X_train,y_train)
# Out:
# [0.96916884 0.08175957 0.37330865 0.86499468 0.5743071  0.44840995
#  0.08746351 0.72800497 0.87699582 0.19239713 0.40950218]
# 3.299034314595876
# 1.712696620941053
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Input In [47], in <cell line: 10>()
#       6 # print(df_features)
#       8 X_train , X_test , y_train , y_test = train_test_split(x_data.to_numpy(), y_data.to_numpy(), test_size=0.33)
# ---> 10 logistic_regression(X_train,y_train)
#
# Input In [46], in logistic_regression(x, y)
#      25         y_cap.append(0)
#      27     if y_cap[i] != y[i]:
# ---> 28         w = w + (y[i]-sig_value)*eta*x_data[i]
#      29         convergence = False
#      30 print(y_cap,y)
#
# UnboundLocalError: local variable 'w' referenced before assignment

# %%
print(X_train,y_train)
