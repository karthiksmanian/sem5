# %%
import matplotlib.pyplot as plot
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("D:/PSG/PSG-Z/SEM 5/20XW58 MACHINE LEARNING LAB/practice/datasets/data.csv")
del df['id']
del df['Unnamed: 32']

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
le = LabelEncoder()

df['diagnosis'] = le.fit_transform(df['diagnosis'])

# %%
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
features = df.columns[1:]

# %%
def remove_multicollinearity(features):
    final_features = [x for x in features]
    
    CR = df[features].corr().values.tolist()
    
    for i in range(len(CR)):
        for j in range(i+1,len(CR)):
            if abs(CR[i][j])>0.7 and features[i] in final_features:
                final_features.remove(features[i])
    return final_features

# %%
final_features = remove_multicollinearity(features)

# %%
df[final_features]
# Out:
#      symmetry_mean  texture_se  smoothness_se  concave points_se  symmetry_se  \
# 0           0.2419      0.9053       0.006399            0.01587      0.03003
# 1           0.1812      0.7339       0.005225            0.01340      0.01389
# 2           0.2069      0.7869       0.006150            0.02058      0.02250
# 3           0.2597      1.1560       0.009110            0.01867      0.05963
# 4           0.1809      0.7813       0.011490            0.01885      0.01756
# ..             ...         ...            ...                ...          ...
# 564         0.1726      1.2560       0.010300            0.02454      0.01114
# 565         0.1752      2.4630       0.005769            0.01678      0.01898
# 566         0.1590      1.0750       0.005903            0.01557      0.01318
# 567         0.2397      1.5950       0.006522            0.01664      0.02324
# 568         0.1587      1.4280       0.007189            0.00000      0.02676
#
# ...

# %%
X = df[final_features]
Y = df['diagnosis']

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
def logistic_regression(x,y):
    W = np.random.rand(x.shape[1]+1)
    eta = 0.5
    convergence = True
    y_cap = [None]*len(y)
    epochs = 0
    Wnew = np.random.rand(x.shape[1]+1)
    
    while(convergence):
        
        
        for i in range(len(x)):
            wTx = W.dot(np.insert(x[i],0,1))
 
            if(sigmoid(wTx)>=0.5):
                y_cap[i] = 1
            else:
                y_cap[i] = 0
                
            if(y_cap[i]!=y[i]):
                Wnew = W + eta*(y[i]-y_cap[i])*y_cap[i]*(1-y_cap[i])*np.insert(x[i],0,1)
            
            W = Wnew
    
        epochs += 1
        if(epochs==6000):    
            convergence = False
    
    return W

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X.to_numpy(),Y.to_numpy(),test_size=0.33)

# %%
weights = logistic_regression(X_train,Y_train)

# %%
def model_testing(W,X,Y):
    Y_cap = [None]*len(Y)
    X = list(X)
    for i in range(len(X)):
        wTx = W.dot(np.insert(X[i],0,1))
        
        if(sigmoid(wTx)>=0.5):
            Y_cap[i] = 1
        else:
            Y_cap[i] = 0
    
    return Y_cap

# %%
Y_pred = model_testing(weights,X_test,Y_test)

# %%
def metrics_check(y,y_cap):
    count = 0
    
    for i in range(len(y)):
        if(y[i]==y_cap[i]):
            count += 1
            
    return count/len(y)

# %%
acc = metrics_check(Y_test,Y_pred)

# %%
print(f"the accuracy of the model is : {acc}")
# Out:
# the accuracy of the model is : 0.3351063829787234
